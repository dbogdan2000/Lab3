# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 uninstall tensorflow 
# !pip3 install tensorflow-gpu==1.14
# Out:
# Uninstalling tensorflow-2.2.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 42kB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.29.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.9.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.3.3)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.18.4)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.1)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 42.0MB/s
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 36.7MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.34.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14) (46.4.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.1.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
import os
os.chdir("/content/drive/My Drive/SMOMI/Lab3/3)")
# !ls
# Out:
# lab3.3m3v4.ipynb  model3.h5  output  version1  version2  version3

# %%
import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
LOG_DIR = './logs'
SHUFFLE_BUFFER = 10
BATCH_SIZE = 8
NUM_CLASSES = 2
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 5216
VALSET_SIZE=624

# %%
def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize_images(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], example['image/class/label']

    
def normalize(image, label):
    return tf.image.per_image_standardization(image), label


def resize(image, label):
    return tf.image.resize_images(image, tf.constant([RESIZE_TO, RESIZE_TO])), label
    
def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames) \
        .map(parse_proto_example) \
        .map(resize) \
        .map(normalize) \
        .map(resize) \
        .shuffle(buffer_size=5 * batch_size) \
        .repeat() \
        .batch(batch_size) \
        .prefetch(2 * batch_size)

class Validation(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, validation_files, batch_size):
        self.log_dir = log_dir
        self.validation_files = validation_files
        self.batch_size = batch_size

    def on_epoch_end(self, epoch, logs=None):
        print('The average loss for epoch {} is {:7.2f} '.format(
            epoch, logs['loss']
        ))

        validation_dataset = create_dataset(self.validation_files, self.batch_size)
        validation_images, validation_labels = validation_dataset.make_one_shot_iterator().get_next()
        validation_labels = tf.one_hot(validation_labels, NUM_CLASSES)

        result = self.model.evaluate(
            validation_images,
            validation_labels,
            steps=int(np.ceil(VALSET_SIZE / float(BATCH_SIZE)))
        )
        callback = tf.keras.callbacks.TensorBoard(log_dir=self.log_dir, update_freq='epoch', batch_size=self.batch_size)

        callback.set_model(self.model)
        callback.on_epoch_end(epoch, {
            'val_' + self.model.metrics_names[i]: v for i, v in enumerate(result)
        })

# %%
def build_model():
    model = keras.models.load_model('model3.h5')
    model.trainable = True
    return model

# %%
train_path = './output/train*'
test_path = './output/test*'

# %%
def main():
    train_dataset = create_dataset(glob.glob(train_path), BATCH_SIZE)
    train_images, train_labels = train_dataset.make_one_shot_iterator().get_next()
    train_labels = tf.one_hot(train_labels, NUM_CLASSES)

    model = build_model()

    model.compile(
        optimizer=keras.optimizers.sgd(lr=0.00000000002, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
        target_tensors=[train_labels]
    )

    log_dir='{}/xray-{}'.format(LOG_DIR, time.time())
    model.fit(
        (train_images, train_labels),
        epochs=80, 
        steps_per_epoch=int(np.ceil(TRAINSET_SIZE / float(BATCH_SIZE))),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            Validation(log_dir, validation_files=glob.glob(test_path), batch_size=BATCH_SIZE)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5215The average loss for epoch 0 is    0.05
# 78/78 [==============================] - 16s 204ms/step - loss: 0.4174 - categorical_accuracy: 0.7212
# 652/652 [==============================] - 95s 146ms/step - loss: 0.0486 - categorical_accuracy: 0.5213
# Epoch 2/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5221The average loss for epoch 1 is    0.05
# 78/78 [==============================] - 12s 152ms/step - loss: 1.7314e-04 - categorical_accuracy: 0.2500
# 652/652 [==============================] - 89s 136ms/step - loss: 0.0486 - categorical_accuracy: 0.5213
# Epoch 3/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5228The average loss for epoch 2 is    0.05
# 78/78 [==============================] - 15s 192ms/step - loss: 0.2755 - categorical_accuracy: 0.4311
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0486 - categorical_accuracy: 0.5228
# Epoch 4/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0484 - categorical_accuracy: 0.5217The average loss for epoch 3 is    0.05
# 78/78 [==============================] - 14s 180ms/step - loss: 0.1679 - categorical_accuracy: 0.4599
# 652/652 [==============================] - 92s 141ms/step - loss: 0.0486 - categorical_accuracy: 0.5224
# Epoch 5/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5232The average loss for epoch 4 is    0.05
# 78/78 [==============================] - 14s 182ms/step - loss: 0.2307 - categorical_accuracy: 0.5465
# 652/652 [==============================] - 91s 140ms/step - loss: 0.0486 - categorical_accuracy: 0.5230
# Epoch 6/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5228The average loss for epoch 5 is    0.05
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2516
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0486 - categorical_accuracy: 0.5224
# Epoch 7/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5228The average loss for epoch 6 is    0.05
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2516
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0486 - categorical_accuracy: 0.5226
# Epoch 8/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5228The average loss for epoch 7 is    0.05
# 78/78 [==============================] - 12s 152ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2548
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0486 - categorical_accuracy: 0.5230
# Epoch 9/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5230The average loss for epoch 8 is    0.05
# 78/78 [==============================] - 16s 205ms/step - loss: 0.3464 - categorical_accuracy: 0.5304
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0486 - categorical_accuracy: 0.5228
# Epoch 10/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0483 - categorical_accuracy: 0.5223The average loss for epoch 9 is    0.05
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0945 - categorical_accuracy: 0.3782
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0484 - categorical_accuracy: 0.5230
# Epoch 11/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5232The average loss for epoch 10 is    0.05
# 78/78 [==============================] - 12s 160ms/step - loss: 0.0899 - categorical_accuracy: 0.2821
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0486 - categorical_accuracy: 0.5228
# Epoch 12/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0483 - categorical_accuracy: 0.5227The average loss for epoch 11 is    0.05
# 78/78 [==============================] - 18s 224ms/step - loss: 0.3408 - categorical_accuracy: 0.6731
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0486 - categorical_accuracy: 0.5232
# Epoch 13/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5232The average loss for epoch 12 is    0.05
# 78/78 [==============================] - 15s 188ms/step - loss: 0.2493 - categorical_accuracy: 0.4167
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0487 - categorical_accuracy: 0.5230
# Epoch 14/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5234The average loss for epoch 13 is    0.05
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0116 - categorical_accuracy: 0.2788
# 652/652 [==============================] - 92s 142ms/step - loss: 0.0487 - categorical_accuracy: 0.5240
# Epoch 15/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5234The average loss for epoch 14 is    0.05
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5236
# Epoch 16/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5240The average loss for epoch 15 is    0.05
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5238
# Epoch 17/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5236The average loss for epoch 16 is    0.05
# 78/78 [==============================] - 13s 168ms/step - loss: 0.1754 - categorical_accuracy: 0.3205
# 652/652 [==============================] - 90s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5232
# Epoch 18/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0485 - categorical_accuracy: 0.5230The average loss for epoch 17 is    0.05
# 78/78 [==============================] - 13s 171ms/step - loss: 0.2741 - categorical_accuracy: 0.5849
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0486 - categorical_accuracy: 0.5238
# Epoch 19/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5246The average loss for epoch 18 is    0.05
# 78/78 [==============================] - 12s 152ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 90s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5240
# Epoch 20/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5250The average loss for epoch 19 is    0.05
# 78/78 [==============================] - 19s 243ms/step - loss: 0.4170 - categorical_accuracy: 0.6090
# 652/652 [==============================] - 95s 145ms/step - loss: 0.0487 - categorical_accuracy: 0.5247
# Epoch 21/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0481 - categorical_accuracy: 0.5236The average loss for epoch 20 is    0.05
# 78/78 [==============================] - 12s 154ms/step - loss: 0.1016 - categorical_accuracy: 0.3125
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0484 - categorical_accuracy: 0.5243
# Epoch 22/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0482 - categorical_accuracy: 0.5236The average loss for epoch 21 is    0.05
# 78/78 [==============================] - 13s 161ms/step - loss: 0.1772 - categorical_accuracy: 0.4904
# 652/652 [==============================] - 88s 136ms/step - loss: 0.0484 - categorical_accuracy: 0.5243
# Epoch 23/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5240The average loss for epoch 22 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 89s 136ms/step - loss: 0.0487 - categorical_accuracy: 0.5240
# Epoch 24/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5257The average loss for epoch 23 is    0.05
# 78/78 [==============================] - 12s 151ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0487 - categorical_accuracy: 0.5257
# Epoch 25/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5244The average loss for epoch 24 is    0.05
# 78/78 [==============================] - 12s 149ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0487 - categorical_accuracy: 0.5243
# Epoch 26/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5261The average loss for epoch 25 is    0.05
# 78/78 [==============================] - 16s 208ms/step - loss: 0.4377 - categorical_accuracy: 0.6538
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5255
# Epoch 27/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5253The average loss for epoch 26 is    0.05
# 78/78 [==============================] - 11s 146ms/step - loss: 0.0020 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0488 - categorical_accuracy: 0.5249
# Epoch 28/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5259The average loss for epoch 27 is    0.05
# 78/78 [==============================] - 14s 184ms/step - loss: 0.2401 - categorical_accuracy: 0.3846
# 652/652 [==============================] - 90s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5257
# Epoch 29/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0484 - categorical_accuracy: 0.5246The average loss for epoch 28 is    0.05
# 78/78 [==============================] - 15s 191ms/step - loss: 0.2083 - categorical_accuracy: 0.5128
# 652/652 [==============================] - 91s 140ms/step - loss: 0.0486 - categorical_accuracy: 0.5253
# Epoch 30/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5257The average loss for epoch 29 is    0.05
# 78/78 [==============================] - 14s 176ms/step - loss: 0.2289 - categorical_accuracy: 0.5449
# 652/652 [==============================] - 91s 140ms/step - loss: 0.0487 - categorical_accuracy: 0.5261
# Epoch 31/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5259The average loss for epoch 30 is    0.05
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 88s 135ms/step - loss: 0.0487 - categorical_accuracy: 0.5257
# Epoch 32/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5253The average loss for epoch 31 is    0.05
# 78/78 [==============================] - 12s 150ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0487 - categorical_accuracy: 0.5253
# Epoch 33/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5259The average loss for epoch 32 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 87s 133ms/step - loss: 0.0487 - categorical_accuracy: 0.5261
# Epoch 34/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5269The average loss for epoch 33 is    0.05
# 78/78 [==============================] - 16s 200ms/step - loss: 0.3107 - categorical_accuracy: 0.4808
# 652/652 [==============================] - 92s 141ms/step - loss: 0.0487 - categorical_accuracy: 0.5263
# Epoch 35/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0485 - categorical_accuracy: 0.5257The average loss for epoch 34 is    0.05
# 78/78 [==============================] - 13s 161ms/step - loss: 0.1336 - categorical_accuracy: 0.4151
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5265
# Epoch 36/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5265The average loss for epoch 35 is    0.05
# 78/78 [==============================] - 12s 149ms/step - loss: 0.0410 - categorical_accuracy: 0.2772
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0487 - categorical_accuracy: 0.5261
# Epoch 37/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0486 - categorical_accuracy: 0.5267The average loss for epoch 36 is    0.05
# 78/78 [==============================] - 17s 224ms/step - loss: 0.3810 - categorical_accuracy: 0.6971
# 652/652 [==============================] - 93s 142ms/step - loss: 0.0487 - categorical_accuracy: 0.5272
# Epoch 38/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5273The average loss for epoch 37 is    0.05
# 78/78 [==============================] - 14s 182ms/step - loss: 0.2278 - categorical_accuracy: 0.3702
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5270
# Epoch 39/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0486 - categorical_accuracy: 0.5263The average loss for epoch 38 is    0.05
# 78/78 [==============================] - 12s 151ms/step - loss: 0.0349 - categorical_accuracy: 0.3317
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0488 - categorical_accuracy: 0.5270
# Epoch 40/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5280The average loss for epoch 39 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 87s 134ms/step - loss: 0.0487 - categorical_accuracy: 0.5278
# Epoch 41/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5280The average loss for epoch 40 is    0.05
# 78/78 [==============================] - 12s 149ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 88s 134ms/step - loss: 0.0487 - categorical_accuracy: 0.5274
# Epoch 42/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5273The average loss for epoch 41 is    0.05
# 78/78 [==============================] - 13s 164ms/step - loss: 0.1332 - categorical_accuracy: 0.2949
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5270
# Epoch 43/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0485 - categorical_accuracy: 0.5269The average loss for epoch 42 is    0.05
# 78/78 [==============================] - 14s 176ms/step - loss: 0.3056 - categorical_accuracy: 0.6378
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5276
# Epoch 44/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5276The average loss for epoch 43 is    0.05
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2580
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5276
# Epoch 45/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5275The average loss for epoch 44 is    0.05
# 78/78 [==============================] - 19s 248ms/step - loss: 0.3751 - categorical_accuracy: 0.5785
# 652/652 [==============================] - 98s 150ms/step - loss: 0.0487 - categorical_accuracy: 0.5268
# Epoch 46/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0483 - categorical_accuracy: 0.5275The average loss for epoch 45 is    0.05
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0860 - categorical_accuracy: 0.3526
# 652/652 [==============================] - 91s 140ms/step - loss: 0.0486 - categorical_accuracy: 0.5282
# Epoch 47/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5276The average loss for epoch 46 is    0.05
# 78/78 [==============================] - 13s 170ms/step - loss: 0.2184 - categorical_accuracy: 0.5304
# 652/652 [==============================] - 91s 140ms/step - loss: 0.0489 - categorical_accuracy: 0.5282
# Epoch 48/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5282The average loss for epoch 47 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2580
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5278
# Epoch 49/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5286The average loss for epoch 48 is    0.05
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5284
# Epoch 50/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5282The average loss for epoch 49 is    0.05
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5278
# Epoch 51/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5301The average loss for epoch 50 is    0.05
# 78/78 [==============================] - 17s 214ms/step - loss: 0.4405 - categorical_accuracy: 0.6170
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0487 - categorical_accuracy: 0.5303
# Epoch 52/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5296The average loss for epoch 51 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0067 - categorical_accuracy: 0.2756
# 652/652 [==============================] - 90s 139ms/step - loss: 0.0488 - categorical_accuracy: 0.5299
# Epoch 53/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5303The average loss for epoch 52 is    0.05
# 78/78 [==============================] - 14s 178ms/step - loss: 0.2107 - categorical_accuracy: 0.3285
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5303
# Epoch 54/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5300The average loss for epoch 53 is    0.05
# 78/78 [==============================] - 15s 197ms/step - loss: 0.2511 - categorical_accuracy: 0.5497
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0489 - categorical_accuracy: 0.5307
# Epoch 55/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5315The average loss for epoch 54 is    0.05
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2438 - categorical_accuracy: 0.5096
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5311
# Epoch 56/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5311The average loss for epoch 55 is    0.05
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5314
# Epoch 57/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5317The average loss for epoch 56 is    0.05
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5312
# Epoch 58/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5317The average loss for epoch 57 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 88s 135ms/step - loss: 0.0487 - categorical_accuracy: 0.5312
# Epoch 59/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5328The average loss for epoch 58 is    0.05
# 78/78 [==============================] - 15s 188ms/step - loss: 0.2763 - categorical_accuracy: 0.4279
# 652/652 [==============================] - 93s 142ms/step - loss: 0.0487 - categorical_accuracy: 0.5326
# Epoch 60/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0487 - categorical_accuracy: 0.5315The average loss for epoch 59 is    0.05
# 78/78 [==============================] - 13s 166ms/step - loss: 0.1728 - categorical_accuracy: 0.4647
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0488 - categorical_accuracy: 0.5322
# Epoch 61/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5332The average loss for epoch 60 is    0.05
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0087 - categorical_accuracy: 0.2644
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5328
# Epoch 62/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0486 - categorical_accuracy: 0.5319The average loss for epoch 61 is    0.05
# 78/78 [==============================] - 19s 247ms/step - loss: 0.4219 - categorical_accuracy: 0.6827
# 652/652 [==============================] - 98s 150ms/step - loss: 0.0488 - categorical_accuracy: 0.5324
# Epoch 63/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5338The average loss for epoch 62 is    0.05
# 78/78 [==============================] - 14s 174ms/step - loss: 0.1918 - categorical_accuracy: 0.3349
# 652/652 [==============================] - 90s 139ms/step - loss: 0.0488 - categorical_accuracy: 0.5332
# Epoch 64/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0485 - categorical_accuracy: 0.5328The average loss for epoch 63 is    0.05
# 78/78 [==============================] - 12s 160ms/step - loss: 0.0801 - categorical_accuracy: 0.3686
# 652/652 [==============================] - 90s 138ms/step - loss: 0.0487 - categorical_accuracy: 0.5336
# Epoch 65/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5336The average loss for epoch 64 is    0.05
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5339
# Epoch 66/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5349The average loss for epoch 65 is    0.05
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5345
# Epoch 67/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5340The average loss for epoch 66 is    0.05
# 78/78 [==============================] - 12s 160ms/step - loss: 0.0850 - categorical_accuracy: 0.2837
# 652/652 [==============================] - 91s 140ms/step - loss: 0.0487 - categorical_accuracy: 0.5339
# Epoch 68/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0486 - categorical_accuracy: 0.5334The average loss for epoch 67 is    0.05
# 78/78 [==============================] - 15s 189ms/step - loss: 0.3463 - categorical_accuracy: 0.6827
# 652/652 [==============================] - 93s 142ms/step - loss: 0.0487 - categorical_accuracy: 0.5341
# Epoch 69/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5348The average loss for epoch 68 is    0.05
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5341
# Epoch 70/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5336The average loss for epoch 69 is    0.05
# 78/78 [==============================] - 17s 216ms/step - loss: 0.3416 - categorical_accuracy: 0.5176
# 652/652 [==============================] - 94s 144ms/step - loss: 0.0487 - categorical_accuracy: 0.5341
# Epoch 71/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0482 - categorical_accuracy: 0.5340The average loss for epoch 70 is    0.05
# 78/78 [==============================] - 13s 167ms/step - loss: 0.1032 - categorical_accuracy: 0.3974
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0485 - categorical_accuracy: 0.5347
# Epoch 72/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5346The average loss for epoch 71 is    0.05
# 78/78 [==============================] - 13s 164ms/step - loss: 0.2400 - categorical_accuracy: 0.5353
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0488 - categorical_accuracy: 0.5345
# Epoch 73/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5355The average loss for epoch 72 is    0.05
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 89s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5355
# Epoch 74/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5361The average loss for epoch 73 is    0.05
# 78/78 [==============================] - 12s 152ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 89s 136ms/step - loss: 0.0487 - categorical_accuracy: 0.5357
# Epoch 75/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5365The average loss for epoch 74 is    0.05
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2612
# 652/652 [==============================] - 90s 137ms/step - loss: 0.0487 - categorical_accuracy: 0.5370
# Epoch 76/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5365The average loss for epoch 75 is    0.05
# 78/78 [==============================] - 16s 206ms/step - loss: 0.4151 - categorical_accuracy: 0.6106
# 652/652 [==============================] - 92s 142ms/step - loss: 0.0487 - categorical_accuracy: 0.5368
# Epoch 77/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0485 - categorical_accuracy: 0.5357The average loss for epoch 76 is    0.05
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0265 - categorical_accuracy: 0.3189
# 652/652 [==============================] - 88s 135ms/step - loss: 0.0487 - categorical_accuracy: 0.5364
# Epoch 78/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5357The average loss for epoch 77 is    0.05
# 78/78 [==============================] - 13s 168ms/step - loss: 0.1730 - categorical_accuracy: 0.3045
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0487 - categorical_accuracy: 0.5353
# Epoch 79/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0486 - categorical_accuracy: 0.5359The average loss for epoch 78 is    0.05
# 78/78 [==============================] - 16s 201ms/step - loss: 0.2871 - categorical_accuracy: 0.5946
# 652/652 [==============================] - 91s 139ms/step - loss: 0.0488 - categorical_accuracy: 0.5366
# Epoch 80/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.0488 - categorical_accuracy: 0.5369The average loss for epoch 79 is    0.05
# 78/78 [==============================] - 14s 184ms/step - loss: 0.2563 - categorical_accuracy: 0.4679
# 652/652 [==============================] - 92s 141ms/step - loss: 0.0487 - categorical_accuracy: 0.5364

# %%
# %reload_ext tensorboard       
# %tensorboard --logdir logs
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorboard", line 8, in <module>
#     sys.exit(run_main())
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/main.py", line 59, in run_main
#     program.get_default_assets_zip_provider())
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 144, in __init__
#     self.plugin_loaders = [make_loader(p) for p in plugins]
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 144, in <listcomp>
#     self.plugin_loaders = [make_loader(p) for p in plugins]
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 143, in make_loader
#     raise ValueError("Not a TBLoader or TBPlugin subclass: %s" % plugin)
# ValueError: Not a TBLoader or TBPlugin subclass: <class 'tensorboard_plugin_wit.wit_plugin_loader.WhatIfToolPluginLoader'>
