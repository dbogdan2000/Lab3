# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 uninstall tensorflow 
# !pip3 install tensorflow-gpu==1.14
# Out:
# Uninstalling tensorflow-2.2.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 41kB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.0.8)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 33.2MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.29.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.18.4)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (3.10.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.34.2)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 42.8MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (47.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.2.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.1.0)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
import os
os.chdir("/content/drive/My Drive/SMOMI/Lab3/1)/version1")
# !ls
# Out:
# lab3.1v1.ipynb	output

# %%
import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
LOG_DIR = './logs'
SHUFFLE_BUFFER = 10
BATCH_SIZE = 8
NUM_CLASSES = 2
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 5216
VALSET_SIZE=624

# %%
def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize_images(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], example['image/class/label']

    
def normalize(image, label):
    return tf.image.per_image_standardization(image), label


def resize(image, label):
    return tf.image.resize_images(image, tf.constant([RESIZE_TO, RESIZE_TO])), label
    
def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames) \
        .map(parse_proto_example) \
        .map(resize) \
        .map(normalize) \
        .map(resize) \
        .shuffle(buffer_size=5 * batch_size) \
        .repeat() \
        .batch(batch_size) \
        .prefetch(2 * batch_size)

class Validation(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, validation_files, batch_size):
        self.log_dir = log_dir
        self.validation_files = validation_files
        self.batch_size = batch_size

    def on_epoch_end(self, epoch, logs=None):
        print('The average loss for epoch {} is {:7.2f} '.format(
            epoch, logs['loss']
        ))

        validation_dataset = create_dataset(self.validation_files, self.batch_size)
        validation_images, validation_labels = validation_dataset.make_one_shot_iterator().get_next()
        validation_labels = tf.one_hot(validation_labels, NUM_CLASSES)

        result = self.model.evaluate(
            validation_images,
            validation_labels,
            steps=int(np.ceil(VALSET_SIZE / float(BATCH_SIZE)))
        )
        callback = tf.keras.callbacks.TensorBoard(log_dir=self.log_dir, update_freq='epoch', batch_size=self.batch_size)

        callback.set_model(self.model)
        callback.on_epoch_end(epoch, {
            'val_' + self.model.metrics_names[i]: v for i, v in enumerate(result)
        })

# %%
def build_model():
    return tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=(224,224,3)),
        tf.keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
	      tf.keras.layers.Conv2D(filters=128,kernel_size=(3,3),padding="same", activation="relu"),
	      tf.keras.layers.Conv2D(filters=128,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
	      tf.keras.layers.Conv2D(filters=256,kernel_size=(3,3),padding="same", activation="relu"),
	      tf.keras.layers.Conv2D(filters=256,kernel_size=(3,3),padding="same", activation="relu"),
	      tf.keras.layers.Conv2D(filters=256,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
        tf.keras.layers.Conv2D(filters=512,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.Conv2D(filters=512,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.Conv2D(filters=512,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
        tf.keras.layers.Conv2D(filters=512,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.Conv2D(filters=512,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.Conv2D(filters=512,kernel_size=(3,3),padding="same", activation="relu"),
        tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=4096,activation="relu"),
        tf.keras.layers.Dense(units=4096,activation="relu"),
        tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)
    ])

# %%
train_path = './output/train*'
test_path = './output/test*'

# %%
def main():
    train_dataset = create_dataset(glob.glob(train_path), BATCH_SIZE)
    train_images, train_labels = train_dataset.make_one_shot_iterator().get_next()
    train_labels = tf.one_hot(train_labels, NUM_CLASSES)

    model = build_model()

    model.compile(
        optimizer=keras.optimizers.sgd(lr=0.00000002, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
        target_tensors=[train_labels]
    )

    log_dir='{}/xray-{}'.format(LOG_DIR, time.time())
    model.fit(
        (train_images, train_labels),
        epochs=80, 
        steps_per_epoch=int(np.ceil(TRAINSET_SIZE / float(BATCH_SIZE))),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            Validation(log_dir, validation_files=glob.glob(test_path), batch_size=BATCH_SIZE)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1514: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From <ipython-input-9-a8ee24a83ea3>:3: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1789 - categorical_accuracy: 0.7425The average loss for epoch 0 is    0.18
# 78/78 [==============================] - 17s 219ms/step - loss: 0.5777 - categorical_accuracy: 0.1683
# 652/652 [==============================] - 109s 167ms/step - loss: 0.1786 - categorical_accuracy: 0.7429
# Epoch 2/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1789 - categorical_accuracy: 0.7425The average loss for epoch 1 is    0.18
# 78/78 [==============================] - 12s 160ms/step - loss: 0.0022 - categorical_accuracy: 0.9968
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1786 - categorical_accuracy: 0.7429
# Epoch 3/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1788 - categorical_accuracy: 0.7425The average loss for epoch 2 is    0.18
# 78/78 [==============================] - 16s 202ms/step - loss: 0.3428 - categorical_accuracy: 0.5064
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1786 - categorical_accuracy: 0.7429
# Epoch 4/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.7440The average loss for epoch 3 is    0.18
# 78/78 [==============================] - 15s 193ms/step - loss: 0.2381 - categorical_accuracy: 0.6571
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1785 - categorical_accuracy: 0.7429
# Epoch 5/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1788 - categorical_accuracy: 0.7425The average loss for epoch 4 is    0.18
# 78/78 [==============================] - 15s 191ms/step - loss: 0.3316 - categorical_accuracy: 0.5224
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1785 - categorical_accuracy: 0.7429
# Epoch 6/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.
80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1777 - categorical_accuracy: 0.6369The average loss for epoch 21 is    0.18
# 78/78 [==============================] - 13s 172ms/step - loss: 0.2556 - categorical_accuracy: 0.5529
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1785 - categorical_accuracy: 0.6361
# Epoch 23/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1785 - categorical_accuracy: 0.6070The average loss for epoch 22 is    0.18
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.6554
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1783 - categorical_accuracy: 0.6068
# Epoch 24/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1785 - categorical_accuracy: 0.5536The average loss for epoch 23 is    0.18
# 78/78 [==============================] - 13s 166ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.5737
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1782 - categorical_accuracy: 0.5535
# Epoch 25/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1785 - categorical_accuracy: 0.4962The average loss for epoch 24 is    0.18
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.4679
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1782 - categorical_accuracy: 0.4964
# Epoch 26/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1785 - categorical_accuracy: 0.4457The average loss for epoch 25 is    0.18
# 78/78 [==============================] - 18s 229ms/step - loss: 0.5742 - categorical_accuracy: 0.5737
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1782 - categorical_accuracy: 0.4463
# Epoch 27/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1787 - categorical_accuracy: 0.4278The average loss for epoch 26 is    0.18
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0022 - categorical_accuracy: 0.3205
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1785 - categorical_accuracy: 0.4277
# Epoch 28/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1785 - categorical_accuracy: 0.3831The average loss for epoch 27 is    0.18
# 78/78 [==============================] - 15s 192ms/step - loss: 0.2887 - categorical_accuracy: 0.4647
# 652/652 [==============================] - 97s 149ms/step - loss: 0.1782 - categorical_accuracy: 0.3827
# Epoch 29/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1774 - categorical_accuracy: 0.3491The average loss for epoch 28 is    0.18
# 78/78 [==============================] - 16s 203ms/step - loss: 0.2909 - categorical_accuracy: 0.4263
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1782 - categorical_accuracy: 0.3501
# Epoch 30/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1784 - categorical_accuracy: 0.3322The average loss for epoch 29 is    0.18
# 78/78 [==============================] - 15s 188ms/step - loss: 0.3309 - categorical_accuracy: 0.4631
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1781 - categorical_accuracy: 0.3319
# Epoch 31/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.3168The average loss for epoch 30 is    0.18
# 78/78 [==============================] - 13s 166ms/step - loss: 0.0011 - categorical_accuracy: 0.1106
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1780 - categorical_accuracy: 0.3165
# Epoch 32/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1784 - categorical_accuracy: 0.3005The average loss for epoch 31 is    0.18
# 78/78 [==============================] - 13s 162ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0737
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1781 - categorical_accuracy: 0.3000
# Epoch 33/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1784 - categorical_accuracy: 0.2884The average loss for epoch 32 is    0.18
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0497
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1781 - categorical_accuracy: 0.2882
# Epoch 34/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1784 - categorical_accuracy: 0.2771The average loss for epoch 33 is    0.18
# 78/78 [==============================] - 16s 209ms/step - loss: 0.3907 - categorical_accuracy: 0.5641
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1781 - categorical_accuracy: 0.2768
# Epoch 35/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1773 - categorical_accuracy: 0.2730The average loss for epoch 34 is    0.18
# 78/78 [==============================] - 13s 173ms/step - loss: 0.1876 - categorical_accuracy: 0.2804
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1781 - categorical_accuracy: 0.2742
# Epoch 36/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.2688The average loss for epoch 35 is    0.18
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0477 - categorical_accuracy: 0.0817
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1781 - categorical_accuracy: 0.2684
# Epoch 37/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1774 - categorical_accuracy: 0.2654The average loss for epoch 36 is    0.18
# 78/78 [==============================] - 19s 245ms/step - loss: 0.5316 - categorical_accuracy: 0.7612
# 652/652 [==============================] - 102s 157ms/step - loss: 0.1780 - categorical_accuracy: 0.2663
# Epoch 38/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.2646The average loss for epoch 37 is    0.18
# 78/78 [==============================] - 15s 196ms/step - loss: 0.2674 - categorical_accuracy: 0.3878
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1780 - categorical_accuracy: 0.2642
# Epoch 39/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1772 - categorical_accuracy: 0.2609The average loss for epoch 38 is    0.18
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0632 - categorical_accuracy: 0.0994
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1780 - categorical_accuracy: 0.2621
# Epoch 40/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.2604The average loss for epoch 39 is    0.18
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0064
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1780 - categorical_accuracy: 0.2600
# Epoch 41/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.2592The average loss for epoch 40 is    0.18
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0032
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1780 - categorical_accuracy: 0.2588
# Epoch 42/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1782 - categorical_accuracy: 0.2586The average loss for epoch 41 is    0.18
# 78/78 [==============================] - 14s 174ms/step - loss: 0.1420 - categorical_accuracy: 0.2083
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1780 - categorical_accuracy: 0.2582
# Epoch 43/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1772 - categorical_accuracy: 0.2569The average loss for epoch 42 is    0.18
# 78/78 [==============================] - 15s 195ms/step - loss: 0.4359 - categorical_accuracy: 0.6282
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1780 - categorical_accuracy: 0.2581
# Epoch 44/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1782 - categorical_accuracy: 0.2583The average loss for epoch 43 is    0.18
# 78/78 [==============================] - 13s 162ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0016
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1779 - categorical_accuracy: 0.2579
# Epoch 45/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1782 - categorical_accuracy: 0.2584The average loss for epoch 44 is    0.18
# 78/78 [==============================] - 20s 251ms/step - loss: 0.4835 - categorical_accuracy: 0.7003
# 652/652 [==============================] - 101s 156ms/step - loss: 0.1779 - categorical_accuracy: 0.2581
# Epoch 46/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1771 - categorical_accuracy: 0.2567The average loss for epoch 45 is    0.18
# 78/78 [==============================] - 13s 164ms/step - loss: 0.1242 - categorical_accuracy: 0.1779
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1779 - categorical_accuracy: 0.2579
# Epoch 47/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1776 - categorical_accuracy: 0.2573The average loss for epoch 46 is    0.18
# 78/78 [==============================] - 13s 173ms/step - loss: 0.3005 - categorical_accuracy: 0.4327
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1780 - categorical_accuracy: 0.2579
# Epoch 48/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1781 - categorical_accuracy: 0.2579The average loss for epoch 47 is    0.18
# 78/78 [==============================] - 13s 160ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0016
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1779 - categorical_accuracy: 0.2575
# Epoch 49/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1781 - categorical_accuracy: 0.2579The average loss for epoch 48 is    0.18
# 78/78 [==============================] - 13s 163ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0016
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1779 - categorical_accuracy: 0.2575
# Epoch 50/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1781 - categorical_accuracy: 0.2579The average loss for epoch 49 is    0.18
# 78/78 [==============================] - 13s 163ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0016
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1778 - categorical_accuracy: 0.2575
# Epoch 51/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1781 - categorical_accuracy: 0.2575The average loss for epoch 50 is    0.18
# 78/78 [==============================] - 17s 222ms/step - loss: 0.5664 - categorical_accuracy: 0.8189
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1778 - categorical_accuracy: 0.2571
# Epoch 52/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1772 - categorical_accuracy: 0.2561The average loss for epoch 51 is    0.18
# 78/78 [==============================] - 13s 162ms/step - loss: 0.
80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1779 - categorical_accuracy: 0.2575The average loss for epoch 66 is    0.18
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0886 - categorical_accuracy: 0.1282
# 652/652 [==============================] - 92s 142ms/step - loss: 0.1776 - categorical_accuracy: 0.2571
# Epoch 68/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1768 - categorical_accuracy: 0.2560The average loss for epoch 67 is    0.18
# 78/78 [==============================] - 15s 191ms/step - loss: 0.4881 - categorical_accuracy: 0.7067
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1776 - categorical_accuracy: 0.2571
# Epoch 69/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.2575The average loss for epoch 68 is    0.18
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0000e+00
# 652/652 [==============================] - 92s 142ms/step - loss: 0.1776 - categorical_accuracy: 0.2571
# Epoch 70/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.2575The average loss for epoch 69 is    0.18
# 78/78 [==============================] - 17s 224ms/step - loss: 0.4294 - categorical_accuracy: 0.6218
# 652/652 [==============================] - 97s 149ms/step - loss: 0.1775 - categorical_accuracy: 0.2571
# Epoch 71/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1767 - categorical_accuracy: 0.2560The average loss for epoch 70 is    0.18
# 78/78 [==============================] - 14s 173ms/step - loss: 0.1483 - categorical_accuracy: 0.2147
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1775 - categorical_accuracy: 0.2571
# Epoch 72/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.2575The average loss for epoch 71 is    0.18
# 78/78 [==============================] - 14s 174ms/step - loss: 0.3286 - categorical_accuracy: 0.4760
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1777 - categorical_accuracy: 0.2573
# Epoch 73/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.2575The average loss for epoch 72 is    0.18
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0000e+00
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1775 - categorical_accuracy: 0.2571
# Epoch 74/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.2575The average loss for epoch 73 is    0.18
# 78/78 [==============================] - 12s 160ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0000e+00
# 652/652 [==============================] - 94s 145ms/step - loss: 0.1775 - categorical_accuracy: 0.2571
# Epoch 75/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1777 - categorical_accuracy: 0.2575The average loss for epoch 74 is    0.18
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.0000e+00
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1775 - categorical_accuracy: 0.2571
# Epoch 76/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1777 - categorical_accuracy: 0.2575The average loss for epoch 75 is    0.18
# 78/78 [==============================] - 17s 219ms/step - loss: 0.5309 - categorical_accuracy: 0.7692
# 652/652 [==============================] - 97s 149ms/step - loss: 0.1775 - categorical_accuracy: 0.2571
# Epoch 77/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1767 - categorical_accuracy: 0.2560The average loss for epoch 76 is    0.18
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0453 - categorical_accuracy: 0.0657
# 652/652 [==============================] - 91s 140ms/step - loss: 0.1774 - categorical_accuracy: 0.2571
# Epoch 78/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1777 - categorical_accuracy: 0.2575The average loss for epoch 77 is    0.18
# 78/78 [==============================] - 14s 175ms/step - loss: 0.1814 - categorical_accuracy: 0.2628
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1774 - categorical_accuracy: 0.2571
# Epoch 79/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1766 - categorical_accuracy: 0.2560The average loss for epoch 78 is    0.18
# 78/78 [==============================] - 16s 207ms/step - loss: 0.3959 - categorical_accuracy: 0.5737
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1774 - categorical_accuracy: 0.2571
# Epoch 80/80
# 651/652 [============================>.] - ETA: 0s - loss: 0.1777 - categorical_accuracy: 0.2575The average loss for epoch 79 is    0.18
# 78/78 [==============================] - 14s 184ms/step - loss: 0.3273 - categorical_accuracy: 0.4744
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1774 - categorical_accuracy: 0.2571

# %%
# %reload_ext tensorboard    
# %tensorboard --logdir logs
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorboard", line 8, in <module>
#     sys.exit(run_main())
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/main.py", line 59, in run_main
#     program.get_default_assets_zip_provider())
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 144, in __init__
#     self.plugin_loaders = [make_loader(p) for p in plugins]
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 144, in <listcomp>
#     self.plugin_loaders = [make_loader(p) for p in plugins]
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 143, in make_loader
#     raise ValueError("Not a TBLoader or TBPlugin subclass: %s" % plugin)
# ValueError: Not a TBLoader or TBPlugin subclass: <class 'tensorboard_plugin_wit.wit_plugin_loader.WhatIfToolPluginLoader'>
